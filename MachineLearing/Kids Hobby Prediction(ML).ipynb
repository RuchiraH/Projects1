# %% [markdown]
# # Kids Hobby Prediction(ML)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
print("\t\t\t******************************Kids Hobby Prediction******************************\n\t\t\tAn attempt to decide the child's area of interest through this dataset.")
# Out:
# 			******************************Kids Hobby Prediction******************************
# 			An attempt to decide the child's area of interest through this dataset.

# %%
df=pd.read_csv("Hobby_data.csv")

# %%
df
# Out:
#      Olympiad_Participation Scholarship School       Fav_sub Projects  \
# 0                       Yes         Yes    Yes   Mathematics      Yes
# 1                       Yes         Yes    Yes   Mathematics      Yes
# 2                       Yes         Yes    Yes       Science      Yes
# 3                       Yes         Yes    Yes   Mathematics      Yes
# 4                       Yes         Yes    Yes       Science      Yes
# ...                     ...         ...    ...           ...      ...
# 1596                     No          No    Yes       Science       No
# 1597                    Yes          No    Yes  Any language      Yes
# 1598                    Yes          No    Yes  Any language       No
# 1599                    Yes         Yes    Yes  Any language       No
# 1600                    Yes          No     No   Mathematics      Yes
#
#       Grasp_pow  Time_sprt Medals Career_sprt Act_sprt Fant_arts Won_arts  \
# ...

# %%
print("\t\t\t\t************** UNDERSTANDING OF DATA GIVEN ***************\n\n"
      "(a) Olympiad_Participation	Has your child participated in any Science/Maths Olympiad?\n\n"
      "(b) Scholarship	Has he/she received any scholarship?\n\n"
      "(c) School	Love's going to school?\n\n"
      "(d) Fav_sub	What is his/her favorite subject?\n\n"
      "(e) Projects	Has done any projects under academics before?\n\n"
      "(f) Grasp_pow	His/Her Grasping power (1-6)\n\n"
      "(g) Time_sprt	How much time does he/she spend playing outdoor/indoor games?\n\n"
      "(h) Medals	Medals won in Sports?\n\n"
      "(i) Career_sprt	Want's to pursue his/her career in sports?\n\n"
      "(j) Act_sprt	Regular in his/her sports activities?\n\n"
      "(k) Fant_arts	Love creating fantasy paintings?\n\n"
      "(l) Won_arts	Won art competitions?\n\n"
      "(m) Time_art	Time utilized in Arts?.")
# Out:
# 				************** UNDERSTANDING OF DATA GIVEN ***************
#
# (a) Olympiad_Participation	Has your child participated in any Science/Maths Olympiad?
#
# (b) Scholarship	Has he/she received any scholarship?
#
# (c) School	Love's going to school?
#
# (d) Fav_sub	What is his/her favorite subject?
#
# (e) Projects	Has done any projects under academics before?
#
# (f) Grasp_pow	His/Her Grasping power (1-6)
#
# (g) Time_sprt	How much time does he/she spend playing outdoor/indoor games?
#
# (h) Medals	Medals won in Sports?
#
# (i) Career_sprt	Want's to pursue his/her career in sports?
#
# (j) Act_sprt	Regular in his/her sports activities?
#
# (k) Fant_arts	Love creating fantasy paintings?
#
# (l) Won_arts	Won art competitions?
#
# (m) Time_art	Time utilized in Arts?.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1601 entries, 0 to 1600
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Olympiad_Participation  1601 non-null   object
#  1   Scholarship             1601 non-null   object
#  2   School                  1601 non-null   object
#  3   Fav_sub                 1601 non-null   object
#  4   Projects                1601 non-null   object
#  5   Grasp_pow               1601 non-null   int64
#  6   Time_sprt               1601 non-null   int64
#  7   Medals                  1601 non-null   object
#  8   Career_sprt             1601 non-null   object
#  9   Act_sprt                1601 non-null   object
#  10  Fant_arts               1601 non-null   object
#  11  Won_arts                1601 non-null   object
#  12  Time_art                1601 non-null   int64
#  13  Predicted Hobby         1601 non-null   object
# ...

# %%
print("\t\t\t******************************Analysis******************************\n\t\t\t\t\tMy Dataset has 14 Columns AND 1601 Rows\n\t\t\t\tIt has 3 Numerical columns and 11 categorical columns\n\t\t\t\t\t\t")
# Out:
# 			******************************Analysis******************************
# 					My Dataset has 14 Columns AND 1601 Rows
# 				It has 3 Numerical columns and 11 categorical columns

# %%
df.describe()
# Out:
#          Grasp_pow    Time_sprt     Time_art
# count  1601.000000  1601.000000  1601.000000
# mean      3.480325     3.033729     2.234229
# std       1.006737     1.347725     1.266186
# min       1.000000     1.000000     1.000000
# 25%       3.000000     2.000000     1.000000
# 50%       3.000000     3.000000     2.000000
# 75%       4.000000     4.000000     3.000000
# max       6.000000     6.000000     6.000000

# %%
df.describe(include="O")
# Out:
#        Olympiad_Participation Scholarship School      Fav_sub Projects Medals  \
# count                    1601        1601   1601         1601     1601   1601
# unique                      2           2      2            4        2      2
# top                       Yes          No    Yes  Mathematics      Yes    Yes
# freq                      822         933   1160          680      926    844
#
#        Career_sprt Act_sprt Fant_arts Won_arts Predicted Hobby
# count         1601     1601      1601     1601            1601
# unique           2        2         2        3               3
# top             No      Yes        No       No       Academics
# freq          1005      891       908      833             699

# %% [markdown]
# ### Cleaning Dataset

# %%
df.isnull().any()
# Out:
# Olympiad_Participation    False
# Scholarship               False
# School                    False
# Fav_sub                   False
# Projects                  False
# Grasp_pow                 False
# Time_sprt                 False
# Medals                    False
# Career_sprt               False
# Act_sprt                  False
# Fant_arts                 False
# Won_arts                  False
# Time_art                  False
# Predicted Hobby           False
# dtype: bool

# %%
print("\t\t\t******************************Analysis******************************\n\t\tWe can clearly see False in output of all columns which means it does not contains null values")
# Out:
# 			******************************Analysis******************************
# 		We can clearly see False in output of all columns which means it does not contains null values

# %%
df.drop('Time_art', axis =1, inplace = True)

# %%
print("\t\t\t******************************Analysis******************************\n\t\t\t\t\t\tDropping Unwanted Column")
# Out:
# 			******************************Analysis******************************
# 						Dropping Unwanted Column

# %% [markdown]
# ### 1)What are the predominant hobbies in the dataset?

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Predicted Hobby', data=df, palette='viridis')
plt.title('Distribution of Predicted Hobby')
plt.xlabel('Predicted Hobby')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### The dataset analysis indicates a predominant interest in academic hobbies among kids, particularly in mathematics and science. Conversely, there is a lesser predicted interest in arts-related hobbies, suggesting a notable imbalance in the dataset.

# %%
fav_sub_counts = df['Fav_sub'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(fav_sub_counts, labels=fav_sub_counts.index, autopct='%1.1f%%', startangle=90)
plt.title('Distribution of Favorite Subjects')
plt.show()

# %% [markdown]
# ### The pie chart depicting favorite subjects indicates a predominant interest in mathematics among students. Conversely, history and geography appear to be the least favored subjects.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Grasp_pow'], bins=20, kde=True, color='skyblue')
plt.title('Distribution of Grasp Power')
plt.xlabel('Grasp Power')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Within the range of 1 to 6, the graph highlights that grasp power rating 3 is most common among students, while rating 1 is least prevalent.

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Time_sprt'], bins=20, kde=True, color='lightcoral')
plt.title('Distribution of Time Spent on Sports')
plt.xlabel('Time Spent on Sports')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### The 'Time_sprt' histogram reveals a peak at 3 hours, indicating the most common time spent on sports among students, while 5 hours is the least prevalent, suggesting a moderate trend in sports engagement.

# %%
df['Predicted Hobby'].replace(['Academics','Sports','Arts'],[0,1,2],inplace=True)
df['Predicted Hobby']=df['Predicted Hobby'].astype(int)

# %%
print("\t\t\t******************************Analysis******************************\n\t\t\t\tConverting target column into numeric column")
# Out:
# 			******************************Analysis******************************
# 				Converting target column into numeric column

# %% [markdown]
# ### Seperating x and y

# %%
x= df.iloc[:,:-1]
x
# Out:
#      Olympiad_Participation Scholarship School       Fav_sub Projects  \
# 0                       Yes         Yes    Yes   Mathematics      Yes
# 1                       Yes         Yes    Yes   Mathematics      Yes
# 2                       Yes         Yes    Yes       Science      Yes
# 3                       Yes         Yes    Yes   Mathematics      Yes
# 4                       Yes         Yes    Yes       Science      Yes
# ...                     ...         ...    ...           ...      ...
# 1596                     No          No    Yes       Science       No
# 1597                    Yes          No    Yes  Any language      Yes
# 1598                    Yes          No    Yes  Any language       No
# 1599                    Yes         Yes    Yes  Any language       No
# 1600                    Yes          No     No   Mathematics      Yes
#
#       Grasp_pow  Time_sprt Medals Career_sprt Act_sprt Fant_arts Won_arts
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1596    1
# 1597    1
# 1598    1
# 1599    1
# 1600    1
# Name: Predicted Hobby, Length: 1601, dtype: int32

# %% [markdown]
# ### Converting 'x' categorical column into numeric column

# %%
cat_col =x.select_dtypes(object).columns

# %%
cat_col
# Out:
# Index(['Olympiad_Participation', 'Scholarship', 'School', 'Fav_sub',
#        'Projects', 'Medals', 'Career_sprt', 'Act_sprt', 'Fant_arts',
#        'Won_arts'],
#       dtype='object')

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
x[cat_col] =oe.fit_transform(x[cat_col])

# %%
x
# Out:
#       Olympiad_Participation  Scholarship  School  Fav_sub  Projects  \
# 0                        1.0          1.0     1.0      2.0       1.0
# 1                        1.0          1.0     1.0      2.0       1.0
# 2                        1.0          1.0     1.0      3.0       1.0
# 3                        1.0          1.0     1.0      2.0       1.0
# 4                        1.0          1.0     1.0      3.0       1.0
# ...                      ...          ...     ...      ...       ...
# 1596                     0.0          0.0     1.0      3.0       0.0
# 1597                     1.0          0.0     1.0      0.0       1.0
# 1598                     1.0          0.0     1.0      0.0       0.0
# 1599                     1.0          1.0     1.0      0.0       0.0
# 1600                     1.0          0.0     0.0      2.0       1.0
#
#       Grasp_pow  Time_sprt  Medals  Career_sprt  Act_sprt  Fant_arts  Won_arts
# ...

# %%
y.unique()
# Out:
# array([0, 2, 1])

# %%
x.shape
# Out:
# (1601, 12)

# %%
y.shape
# Out:
# (1601,)

# %%
y.value_counts()
# Out:
# 0    699
# 1    492
# 2    410
# Name: Predicted Hobby, dtype: int64

# %% [markdown]
# #### As you can see target column is slightly imbalanced

# %% [markdown]
# ### Spliting the data

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.25,random_state=1)

# %% [markdown]
# ### 1)Predicting the data using Logistics Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression() 
logreg.fit(xtrain,ytrain)
ypred=logreg.predict(xtest)

# %%
from sklearn.metrics import accuracy_score,classification_report
ac = accuracy_score(ytest,ypred)
cr = classification_report(ytest,ypred)
print("Accuracy score : ",ac)
print(cr)
# Out:
# Accuracy score :  0.8977556109725686
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       184
#            1       0.90      0.93      0.92       123
#            2       0.83      0.88      0.86        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.89       401
# weighted avg       0.90      0.90      0.90       401

# %% [markdown]
# ### We have achieved an Average Accuracy of 90 % . Lets see if we can increase this accuracy by hyper tuning

# %% [markdown]
# ### Using HTP(To increase accuracy we use HTP)

# %% [markdown]
# ### 1)solver = "liblinear"

# %%
logreg = LogisticRegression(solver = "liblinear")
logreg.fit(xtrain,ytrain)
ypred = logreg.predict(xtest)

# %%
ac = accuracy_score(ytest,ypred)
cr = classification_report(ytest,ypred)
print("Accuracy score : ",ac)
print(cr)
# Out:
# Accuracy score :  0.8977556109725686
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       184
#            1       0.91      0.93      0.92       123
#            2       0.83      0.87      0.85        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.89       401
# weighted avg       0.90      0.90      0.90       401

# %% [markdown]
# ### By using liblinear we get Accuracy of 90%

# %% [markdown]
# ### 2) solver = 'newton-cg'

# %%
logreg = LogisticRegression(solver = 'newton-cg')
logreg.fit(xtrain,ytrain)
ypred = logreg.predict(xtest)

# %%
ac = accuracy_score(ytest,ypred)
cr = classification_report(ytest,ypred)
print("Accuracy score : ",ac)
print(cr)
# Out:
# Accuracy score :  0.8977556109725686
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       184
#            1       0.90      0.93      0.92       123
#            2       0.83      0.88      0.86        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.89       401
# weighted avg       0.90      0.90      0.90       401

# %% [markdown]
# ### By using newton-cg we get Accuracy of 90%

# %% [markdown]
# ### 3) solver = 'sag'

# %%
logreg = LogisticRegression(solver = 'sag')
logreg.fit(xtrain,ytrain)
ypred = logreg.predict(xtest)

# %%
ac = accuracy_score(ytest,ypred)
cr = classification_report(ytest,ypred)
print("Accuracy score : ",ac)
print(cr)
# Out:
# Accuracy score :  0.8952618453865336
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       184
#            1       0.90      0.93      0.92       123
#            2       0.83      0.87      0.85        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.89       401
# weighted avg       0.90      0.90      0.90       401

# %% [markdown]
# ### By using sag we get Accuracy of 90%

# %% [markdown]
# ### 4) solver = 'saga'

# %%
logreg = LogisticRegression(solver = 'saga')
logreg.fit(xtrain,ytrain)
ypred = logreg.predict(xtest)

# %%
ac = accuracy_score(ytest,ypred)
cr = classification_report(ytest,ypred)
print("Accuracy score : ",ac)
print(cr)
# Out:
# Accuracy score :  0.8952618453865336
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       184
#            1       0.90      0.93      0.92       123
#            2       0.83      0.87      0.85        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.89       401
# weighted avg       0.90      0.90      0.90       401

# %% [markdown]
# ### By using saga we get Accuracy of 90%

# %% [markdown]
# ### 2)Predicting the data using Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

# %%
dt = DecisionTreeClassifier()

# %%
def mymodel(model):
    model.fit(xtrain,ytrain)
    ypred = model.predict(xtest)
    print(accuracy_score(ytest,ypred))
    print(classification_report(ytest,ypred))
    return model

# %%
mymodel(dt)
# Out:
# 0.9002493765586035
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       184
#            1       0.91      0.89      0.90       123
#            2       0.83      0.90      0.87        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.90       401
# weighted avg       0.90      0.90      0.90       401
# DecisionTreeClassifier()

# %% [markdown]
# ### By using Decision Tree we get average accuracy of 89% which is good but lets check whether we get more accurcy by hyper tunning

# %% [markdown]
# ### Ploting decision tree

# %%
fig,ax=plt.subplots(figsize=(25,10))
chart=tree.plot_tree(dt,feature_names=x.columns,filled=True,fontsize=10)
plt.savefig('Tree1.jpg')

# %%
train = dt.score(xtrain,ytrain)
test = dt.score(xtest,ytest)
print(f"train score :{train} \ntest score : {test}")
# Out:
# train score :0.9925
# test score : 0.9002493765586035

# %%
# as training accuracy is  high then training errors will be low 
# as training accuracy is  low then training errors will be high 
# low bias & High variance = overfitting

# %% [markdown]
# ### max_depth Parameter

# %%
for i in range(1,50):
    dt1=DecisionTreeClassifier(max_depth=i)
    dt1.fit(xtrain,ytrain)
    ypred=dt1.predict(xtest)
    
    ac=accuracy_score(ytest,ypred)
    print(f' max depth: {i}, Accuracy: {ac}')
# Out:
#  max depth: 1, Accuracy: 0.7256857855361596
#  max depth: 2, Accuracy: 0.8827930174563591
#  max depth: 3, Accuracy: 0.8977556109725686
#  max depth: 4, Accuracy: 0.8877805486284289
#  max depth: 5, Accuracy: 0.8952618453865336
#  max depth: 6, Accuracy: 0.9077306733167082
#  max depth: 7, Accuracy: 0.9002493765586035
#  max depth: 8, Accuracy: 0.9077306733167082
#  max depth: 9, Accuracy: 0.8902743142144638
#  max depth: 10, Accuracy: 0.9002493765586035
#  max depth: 11, Accuracy: 0.8877805486284289
#  max depth: 12, Accuracy: 0.8952618453865336
#  max depth: 13, Accuracy: 0.9052369077306733
#  max depth: 14, Accuracy: 0.8902743142144638
#  max depth: 15, Accuracy: 0.8902743142144638
#  max depth: 16, Accuracy: 0.8902743142144638
#  max depth: 17, Accuracy: 0.8902743142144638
#  max depth: 18, Accuracy: 0.8877805486284289
#  max depth: 19, Accuracy: 0.9002493765586035
#  max depth: 20, Accuracy: 0.8827930174563591
#  max depth: 21, Accuracy: 0.885286783042394
# ...

# %%
dt2=DecisionTreeClassifier(max_depth=5)#remake the object everytime
mymodel(dt2)
# Out:
# 0.8952618453865336
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.90       184
#            1       0.92      0.88      0.90       123
#            2       0.80      0.96      0.87        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.89       401
# weighted avg       0.90      0.90      0.90       401
# DecisionTreeClassifier(max_depth=5)

# %% [markdown]
# ### By using Decision Tree Max Depth function we achive the accuracy of 90%

# %%
train = dt2.score(xtrain,ytrain)
test = dt2.score(xtest,ytest)
print(f"train score :{train} \ntest score : {test}")
# Out:
# train score :0.9233333333333333
# test score : 0.8952618453865336

# %% [markdown]
# ### min_sample_split

# %%
for i in range(50,100):
    dt3=DecisionTreeClassifier(min_samples_split=i)
    dt3.fit(xtrain,ytrain)
    ypred=dt3.predict(xtest)
    
    ac=accuracy_score(ytest,ypred)
    print(f' max depth: {i}, Accuracy: {ac}')
# Out:
#  max depth: 50, Accuracy: 0.9027431421446384
#  max depth: 51, Accuracy: 0.9027431421446384
#  max depth: 52, Accuracy: 0.9027431421446384
#  max depth: 53, Accuracy: 0.9027431421446384
#  max depth: 54, Accuracy: 0.8977556109725686
#  max depth: 55, Accuracy: 0.8977556109725686
#  max depth: 56, Accuracy: 0.8977556109725686
#  max depth: 57, Accuracy: 0.8977556109725686
#  max depth: 58, Accuracy: 0.9027431421446384
#  max depth: 59, Accuracy: 0.9027431421446384
#  max depth: 60, Accuracy: 0.9027431421446384
#  max depth: 61, Accuracy: 0.9027431421446384
#  max depth: 62, Accuracy: 0.8977556109725686
#  max depth: 63, Accuracy: 0.8977556109725686
#  max depth: 64, Accuracy: 0.8977556109725686
#  max depth: 65, Accuracy: 0.8977556109725686
#  max depth: 66, Accuracy: 0.8977556109725686
#  max depth: 67, Accuracy: 0.8977556109725686
#  max depth: 68, Accuracy: 0.8977556109725686
#  max depth: 69, Accuracy: 0.8977556109725686
#  max depth: 70, Accuracy: 0.8977556109725686
# ...

# %%
dt4=DecisionTreeClassifier(min_samples_split=54)#remake the object everytime
mymodel(dt4)
# Out:
# 0.8977556109725686
#               precision    recall  f1-score   support
#
#            0       0.95      0.87      0.91       184
#            1       0.90      0.91      0.91       123
#            2       0.81      0.94      0.87        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.91      0.89       401
# weighted avg       0.90      0.90      0.90       401
# DecisionTreeClassifier(min_samples_split=54)

# %% [markdown]
# ### By using Decision Tree Min Sample Split function we achive the accuracy of 90%

# %%
train = dt4.score(xtrain,ytrain)
test = dt4.score(xtest,ytest)
print(f"train score :{train} \ntest score : {test}")
# Out:
# train score :0.8966666666666666
# test score : 0.8977556109725686

# %% [markdown]
# ### min_sample_leaf

# %%
for i in range(1,50):
    dt5=DecisionTreeClassifier(min_samples_leaf=i)
    dt5.fit(xtrain,ytrain)
    ypred=dt5.predict(xtest)
    
    ac=accuracy_score(ytest,ypred)
    print(f' max depth: {i}, Accuracy: {ac}')
# Out:
#  max depth: 1, Accuracy: 0.9027431421446384
#  max depth: 2, Accuracy: 0.9077306733167082
#  max depth: 3, Accuracy: 0.9052369077306733
#  max depth: 4, Accuracy: 0.9177057356608479
#  max depth: 5, Accuracy: 0.9077306733167082
#  max depth: 6, Accuracy: 0.912718204488778
#  max depth: 7, Accuracy: 0.9077306733167082
#  max depth: 8, Accuracy: 0.8927680798004988
#  max depth: 9, Accuracy: 0.8902743142144638
#  max depth: 10, Accuracy: 0.8827930174563591
#  max depth: 11, Accuracy: 0.8827930174563591
#  max depth: 12, Accuracy: 0.8927680798004988
#  max depth: 13, Accuracy: 0.9077306733167082
#  max depth: 14, Accuracy: 0.912718204488778
#  max depth: 15, Accuracy: 0.912718204488778
#  max depth: 16, Accuracy: 0.9102244389027432
#  max depth: 17, Accuracy: 0.9102244389027432
#  max depth: 18, Accuracy: 0.9177057356608479
#  max depth: 19, Accuracy: 0.9177057356608479
#  max depth: 20, Accuracy: 0.9177057356608479
#  max depth: 21, Accuracy: 0.9177057356608479
# ...

# %%
dt6=DecisionTreeClassifier(min_samples_split=28)#remake the object everytime
mymodel(dt6)
# Out:
# 0.9027431421446384
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       184
#            1       0.90      0.90      0.90       123
#            2       0.88      0.88      0.88        94
#
#     accuracy                           0.90       401
#    macro avg       0.90      0.90      0.90       401
# weighted avg       0.90      0.90      0.90       401
# DecisionTreeClassifier(min_samples_split=28)

# %% [markdown]
# ### By using Decision Tree min_samples_leaf function we achive the accuracy of 90%

# %%
train = dt6.score(xtrain,ytrain)
test = dt6.score(xtest,ytest)
print(f"train score :{train} \ntest score : {test}")
# Out:
# train score :0.9183333333333333
# test score : 0.9027431421446384

# %% [markdown]
# ### 3)Predicting the data using Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rc = RandomForestClassifier()
rc.fit(xtrain,ytrain)
ypred = rc.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       184
#            1       0.90      0.93      0.92       123
#            2       0.89      0.87      0.88        94
#
#     accuracy                           0.92       401
#    macro avg       0.91      0.91      0.91       401
# weighted avg       0.92      0.92      0.92       401

# %% [markdown]
# ### By using Random Forest we get 91% of accuracy.

# %% [markdown]
# ### Predicting the data using Boosting

# %% [markdown]
# ### 1)Adaboost Classifier

# %%
from sklearn.ensemble import AdaBoostClassifier
ada = AdaBoostClassifier()
ada.fit(xtrain,ytrain)
ypred = ada.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.91      0.91       184
#            1       0.90      0.90      0.90       123
#            2       0.86      0.85      0.86        94
#
#     accuracy                           0.89       401
#    macro avg       0.89      0.89      0.89       401
# weighted avg       0.89      0.89      0.89       401

# %% [markdown]
# ### By using AdaBoost Classifier we get 89% of accuracy

# %% [markdown]
# ### 2)Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier()
gbc.fit(xtrain,ytrain)
ypred = gbc.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       184
#            1       0.92      0.92      0.92       123
#            2       0.86      0.91      0.89        94
#
#     accuracy                           0.91       401
#    macro avg       0.90      0.91      0.91       401
# weighted avg       0.91      0.91      0.91       401

# %% [markdown]
# ### By using Gradient Boosting algorithm we get 91% of accuracy

# %% [markdown]
# ### 3)XG Boosting

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(xtrain,ytrain)
ypred = xgb.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       184
#            1       0.92      0.90      0.91       123
#            2       0.89      0.90      0.89        94
#
#     accuracy                           0.92       401
#    macro avg       0.91      0.91      0.91       401
# weighted avg       0.92      0.92      0.92       401

# %% [markdown]
# ### By using XG Boost algorithm we get 92% of accuracy

# %% [markdown]
# ### 4)Predicting the data using Encemble Learning

# %% [markdown]
# ## Bagging

# %% [markdown]
# #### 1)Bagging Classifier on Logistic Regression

# %%
from sklearn.ensemble import BaggingClassifier
bg = BaggingClassifier(LogisticRegression())
bg.fit(xtrain,ytrain)
ypred = bg.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91       184
#            1       0.90      0.93      0.92       123
#            2       0.83      0.88      0.86        94
#
#     accuracy                           0.90       401
#    macro avg       0.89      0.90      0.89       401
# weighted avg       0.90      0.90      0.90       401

# %% [markdown]
# ### By using Bagging Classifier on Logistic Regression we get 90% of accuracy which is not good for prediction

# %% [markdown]
# #### 2)Bagging Classifier on DecisionTreeClassifier

# %%
bg = BaggingClassifier(DecisionTreeClassifier())
bg.fit(xtrain,ytrain)
ypred = bg.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92       184
#            1       0.92      0.90      0.91       123
#            2       0.87      0.90      0.89        94
#
#     accuracy                           0.91       401
#    macro avg       0.90      0.91      0.91       401
# weighted avg       0.91      0.91      0.91       401

# %% [markdown]
# ### By using Bagging Classifier on Decision Tree we get 90% of accuracy.

# %% [markdown]
# ### Votting Classifier

# %%
models =[]
models.append(("lr",LogisticRegression()))
models.append(("dt",DecisionTreeClassifier()))

# %%
from sklearn.ensemble import VotingClassifier
vc = VotingClassifier(estimators = models)	# estimators --> model name
vc.fit(xtrain,ytrain)
ypred = vc.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.94      0.92       184
#            1       0.90      0.90      0.90       123
#            2       0.92      0.83      0.87        94
#
#     accuracy                           0.90       401
#    macro avg       0.90      0.89      0.90       401
# weighted avg       0.90      0.90      0.90       401

# %% [markdown]
# ### By using Voting Classifier we get 90% of accuracy.

# %%
from sklearn.ensemble import VotingClassifier
vc = VotingClassifier(estimators = models,voting='soft')
vc.fit(xtrain,ytrain)
ypred = vc.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.91       184
#            1       0.90      0.89      0.89       123
#            2       0.82      0.89      0.86        94
#
#     accuracy                           0.89       401
#    macro avg       0.88      0.89      0.89       401
# weighted avg       0.89      0.89      0.89       401

# %% [markdown]
# ### By using Voting Classifier using soft voting we get 89% of accuracy.

# %% [markdown]
# # Based on the above accuracy scores, we should go ahead with Gradient boosting with accuracy of 91% and XG Boosting with accuracy of 92%.
